# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic
import myrequests as myreq

client = Anthropic()
model = "claude-sonnet-4-0"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 from anthropic import Anthropic
# ----> 2 import myrequests as myreq
#       4 client = Anthropic()
#       5 model = "claude-sonnet-4-0"
#
# ModuleNotFoundError: No module named 'myrequests'

# %%
messages = []
while True:
    #Get User input
    user_input = input("> ")
    print(">", user_input)
