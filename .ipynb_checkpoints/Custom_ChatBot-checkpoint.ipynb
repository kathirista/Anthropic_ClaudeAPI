# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic
import ipynb.fs.full.myrequests as myreq
client = Anthropic()
model = "claude-sonnet-4-0"

# %%
messages = []
while True:
    #Get User input
    user_input = input("> ")
    print(">", user_input)

# %%
myreq.add_user_message(messages,input("Enter user input"))
answer = chat(messages)
add_assistant_messages(messages,answer)

print("---")
print(answer)
print("---")
